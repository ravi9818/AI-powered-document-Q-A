# %%
# %pip install langchain openai faiss-cpu pypdf tiktoken sentence-transformers python-dotenv
# Out:
# Collecting langchain
#   Using cached langchain-1.2.13-py3-none-any.whl.metadata (5.8 kB)
# Collecting openai
#   Using cached openai-2.30.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: faiss-cpu in d:\guvi\myenv\lib\site-packages (1.13.2)
# Requirement already satisfied: pypdf in d:\guvi\myenv\lib\site-packages (6.9.2)
# Collecting tiktoken
#   Using cached tiktoken-0.12.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.3.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: python-dotenv in d:\guvi\myenv\lib\site-packages (1.2.2)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Using cached langchain_core-1.2.22-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.1 (from langchain)
#   Using cached langgraph-1.1.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached langsmith-0.7.22-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\guvi\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.1->langchain)
#   Using cached langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.8 (from langgraph<1.2.0,>=1.1.1->langchain)
#   Using cached langgraph_prebuilt-1.0.8-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.1->langchain)
#   Using cached langgraph_sdk-0.3.12-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in d:\guvi\myenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\guvi\myenv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: orjson>=3.11.5 in d:\guvi\myenv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.13.0)
# Requirement already satisfied: certifi in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2025.10.5)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\guvi\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\guvi\myenv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\guvi\myenv\lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: sniffio in d:\guvi\myenv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\guvi\myenv\lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in d:\guvi\myenv\lib\site-packages (from faiss-cpu) (2.3.2)
# Requirement already satisfied: regex>=2022.1.18 in d:\guvi\myenv\lib\site-packages (from tiktoken) (2026.2.28)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Using cached transformers-5.4.0-py3-none-any.whl.metadata (32 kB)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Using cached huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Using cached torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: scikit-learn in d:\guvi\myenv\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in d:\guvi\myenv\lib\site-packages (from sentence-transformers) (1.16.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: safetensors>=0.4.3 in d:\guvi\myenv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in d:\guvi\myenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\guvi\myenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in d:\guvi\myenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\guvi\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\guvi\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: setuptools<82 in d:\guvi\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\guvi\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\guvi\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in d:\guvi\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\guvi\myenv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in d:\guvi\myenv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\guvi\myenv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.3.0 in d:\guvi\myenv\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in d:\guvi\myenv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: click>=8.2.1 in d:\guvi\myenv\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in d:\guvi\myenv\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in d:\guvi\myenv\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\guvi\myenv\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\guvi\myenv\lib\site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\guvi\myenv\lib\site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\guvi\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Using cached langchain-1.2.13-py3-none-any.whl (112 kB)
# Using cached langchain_core-1.2.22-py3-none-any.whl (506 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langgraph-1.1.3-py3-none-any.whl (168 kB)
# Using cached langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Using cached langgraph_prebuilt-1.0.8-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.3.12-py3-none-any.whl (95 kB)
# Using cached langsmith-0.7.22-py3-none-any.whl (359 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached openai-2.30.0-py3-none-any.whl (1.1 MB)
# Using cached tiktoken-0.12.0-cp313-cp313-win_amd64.whl (879 kB)
# Using cached sentence_transformers-5.3.0-py3-none-any.whl (512 kB)
# Using cached transformers-5.4.0-py3-none-any.whl (10.1 MB)
# Using cached huggingface_hub-1.8.0-py3-none-any.whl (625 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
# Using cached typer-0.24.1-py3-none-any.whl (56 kB)
# Installing collected packages: jsonpatch, httpcore, torch, tiktoken, requests-toolbelt, pydantic, httpx, typer, openai, langsmith, langgraph-sdk, langchain-core, huggingface-hub, tokenizers, langgraph-checkpoint, transformers, langgraph-prebuilt, sentence-transformers, langgraph, langchain
#
#    -- -------------------------------------  1/20 [httpcore]
#    -- -------------------------------------  1/20 [httpcore]
#    -- -------------------------------------  1/20 [httpcore]
#    -- -------------------------------------  1/20 [httpcore]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ---- -----------------------------------  2/20 [torch]
#    ------ ---------------------------------  3/20 [tiktoken]
#
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\GUVI\\myenv\\Lib\\site-packages\\tiktoken\\_tiktoken.cp313-win_amd64.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install --upgrade langchain langchain-community langchain-openai
# Out:
# Requirement already satisfied: langchain in d:\guvi\myenv\lib\site-packages (1.2.13)
# Collecting langchain-community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.12-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in d:\guvi\myenv\lib\site-packages (from langchain) (1.2.22)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in d:\guvi\myenv\lib\site-packages (from langchain) (1.1.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\guvi\myenv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\guvi\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\guvi\myenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in d:\guvi\myenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\guvi\myenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.12)
# Requirement already satisfied: xxhash>=3.5.0 in d:\guvi\myenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\guvi\myenv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\guvi\myenv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\guvi\myenv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.13.0)
# Requirement already satisfied: certifi in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\guvi\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Using cached langchain_classic-1.0.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in d:\guvi\myenv\lib\site-packages (from langchain-community) (2.0.44)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Using cached aiohttp-3.13.3-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Using cached pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=2.1.0 in d:\guvi\myenv\lib\site-packages (from langchain-community) (2.3.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in d:\guvi\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached frozenlist-1.8.0-cp313-cp313-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached multidict-6.7.1-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached propcache-0.4.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached yarl-1.23.0-cp313-cp313-win_amd64.whl.metadata (82 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.1 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Using cached langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\guvi\myenv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\guvi\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\guvi\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in d:\guvi\myenv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in d:\guvi\myenv\lib\site-packages (from langchain-openai) (2.30.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in d:\guvi\myenv\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\guvi\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\guvi\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in d:\guvi\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\guvi\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in d:\guvi\myenv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.2.28)
# Requirement already satisfied: colorama in d:\guvi\myenv\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached aiohttp-3.13.3-cp313-cp313-win_amd64.whl (453 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.3-py3-none-any.whl (1.0 MB)
# Using cached langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached multidict-6.7.1-cp313-cp313-win_amd64.whl (45 kB)
# Using cached pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.23.0-cp313-cp313-win_amd64.whl (87 kB)
# Downloading langchain_openai-1.1.12-py3-none-any.whl (88 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached propcache-0.4.1-cp313-cp313-win_amd64.whl (40 kB)
# Installing collected packages: propcache, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-text-splitters, langchain-openai, langchain-classic, langchain-community
#
#    ------- --------------------------------  3/17 [marshmallow]
#    --------- ------------------------------  4/17 [httpx-sse]
#    ---------------- -----------------------  7/17 [yarl]
#    ----------------------- ---------------- 10/17 [pydantic-settings]
#    ----------------------- ---------------- 10/17 [pydantic-settings]
#    ------------------------- -------------- 11/17 [dataclasses-json]
#    ---------------------------- ----------- 12/17 [aiohttp]
#    ---------------------------- ----------- 12/17 [aiohttp]
#    ---------------------------- ----------- 12/17 [aiohttp]
#    ---------------------------- ----------- 12/17 [aiohttp]
#    ---------------------------- ----------- 12/17 [aiohttp]
#    ---------------------------- ----------- 12/17 [aiohttp]
#    ------------------------------ --------- 13/17 [langchain-text-splitters]
#    -------------------------------- ------- 14/17 [langchain-openai]
#    -------------------------------- ------- 14/17 [langchain-openai]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ----------------------------------- ---- 15/17 [langchain-classic]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ------------------------------------- -- 16/17 [langchain-community]
#    ---------------------------------------- 17/17 [langchain-community]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 dataclasses-json-0.6.7 frozenlist-1.8.0 httpx-sse-0.4.3 langchain-classic-1.0.3 langchain-community-0.4.1 langchain-openai-1.1.12 langchain-text-splitters-1.1.1 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 propcache-0.4.1 pydantic-settings-2.13.1 typing-inspect-0.9.0 yarl-1.23.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip uninstall langchain -y
# %pip uninstall langchain-community -y
# %pip uninstall langchain-openai -y

# %pip install langchain langchain-community langchain-openai
# Out:
# Found existing installation: langchain 1.2.13
# Uninstalling langchain-1.2.13:
#   Successfully uninstalled langchain-1.2.13
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: langchain-openai 1.1.12
# Uninstalling langchain-openai-1.1.12:
#   Successfully uninstalled langchain-openai-1.1.12
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain
#   Using cached langchain-1.2.13-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-openai
#   Using cached langchain_openai-1.1.12-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in d:\guvi\myenv\lib\site-packages (from langchain) (1.2.22)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in d:\guvi\myenv\lib\site-packages (from langchain) (1.1.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\guvi\myenv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\guvi\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\guvi\myenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in d:\guvi\myenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\guvi\myenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.12)
# Requirement already satisfied: xxhash>=3.5.0 in d:\guvi\myenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\guvi\myenv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\guvi\myenv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\guvi\myenv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.13.0)
# Requirement already satisfied: certifi in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\guvi\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\guvi\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in d:\guvi\myenv\lib\site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in d:\guvi\myenv\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\guvi\myenv\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in d:\guvi\myenv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in d:\guvi\myenv\lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\guvi\myenv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in d:\guvi\myenv\lib\site-packages (from langchain-community) (2.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\guvi\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\guvi\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\guvi\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\guvi\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\guvi\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\guvi\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\guvi\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\guvi\myenv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\guvi\myenv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in d:\guvi\myenv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\guvi\myenv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\guvi\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\guvi\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in d:\guvi\myenv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\guvi\myenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in d:\guvi\myenv\lib\site-packages (from langchain-openai) (2.30.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in d:\guvi\myenv\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\guvi\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\guvi\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in d:\guvi\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\guvi\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in d:\guvi\myenv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.2.28)
# Requirement already satisfied: colorama in d:\guvi\myenv\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Using cached langchain-1.2.13-py3-none-any.whl (112 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached langchain_openai-1.1.12-py3-none-any.whl (88 kB)
# Installing collected packages: langchain-openai, langchain-community, langchain
#
#    ---------------------------------------- 0/3 [langchain-openai]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    ---------------------------------------- 3/3 [langchain]
#
# Successfully installed langchain-1.2.13 langchain-community-0.4.1 langchain-openai-1.1.12
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in d:\guvi\myenv\lib\site-packages (1.1.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.13 in d:\guvi\myenv\lib\site-packages (from langchain-text-splitters) (1.2.22)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\guvi\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\guvi\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\guvi\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: anyio in d:\guvi\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (4.13.0)
# Requirement already satisfied: certifi in d:\guvi\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\guvi\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in d:\guvi\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\guvi\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\guvi\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\guvi\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\guvi\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.document_loaders import TextLoader, CSVLoader, JSONLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
import os

# %%
def load_documents_from_folder(folder_path):
    all_docs = []

    for file in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file)

        try:
            if file.endswith(".txt"):
                loader = TextLoader(file_path)
                docs = loader.load()

            elif file.endswith(".csv"):
                loader = CSVLoader(file_path)
                docs = loader.load()

            elif file.endswith(".json"):
                loader = JSONLoader(file_path, jq_schema=".[]")
                docs = loader.load()

            else:
                continue

            # Add metadata (VERY IMPORTANT FOR SOURCE TRACKING)
            for doc in docs:
                doc.metadata["source_file"] = file

            all_docs.extend(docs)

        except Exception as e:
            print(f"Error loading {file}: {e}")

    return all_docs

# %%
# %pip install pandas jq
# Out:
# Requirement already satisfied: pandas in d:\guvi\myenv\lib\site-packages (2.3.3)
# Collecting jq
#   Downloading jq-1.11.0-cp313-cp313-win_amd64.whl.metadata (7.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in d:\guvi\myenv\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\guvi\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\guvi\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\guvi\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\guvi\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading jq-1.11.0-cp313-cp313-win_amd64.whl (409 kB)
# Installing collected packages: jq
# Successfully installed jq-1.11.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
folder_path = "D:\GUVI\myenv\AI_Document_QA_System\Data"   # put all txt/json/csv here
documents = load_documents_from_folder(folder_path)

print("Total documents loaded:", len(documents))
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\ravi9\AppData\Local\Temp\ipykernel_17460\2162740088.py:1: SyntaxWarning: invalid escape sequence '\G'
#   folder_path = "D:\GUVI\myenv\AI_Document_QA_System\Data"   # put all txt/json/csv here
# Error loading data.json: Expecting value: line 1 column 1 (char 0)
# Error loading data.txt: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\data.txt
# Error loading dev-v1.1.json: Expected page_content is string, got <class 'list'> instead.                     Set `text_content=False` if the desired input for                     `page_content` is not a string
# Error loading mlqa-translate-test.ar_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-test.ar_test.csv
# Error loading mlqa-translate-test.de_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-test.de_test.csv
# Error loading mlqa-translate-test.es_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-test.es_test.csv
# Error loading mlqa-translate-test.hi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-test.hi_test.csv
# Error loading mlqa-translate-test.vi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-test.vi_test.csv
# Error loading mlqa-translate-test.zh_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-test.zh_test.csv
# Error loading mlqa-translate-train.ar_train.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.ar_train.csv
# Error loading mlqa-translate-train.ar_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.ar_validation.csv
# Error loading mlqa-translate-train.de_train.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.de_train.csv
# Error loading mlqa-translate-train.de_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.de_validation.csv
# Error loading mlqa-translate-train.es_train.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.es_train.csv
# Error loading mlqa-translate-train.es_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.es_validation.csv
# Error loading mlqa-translate-train.hi_train.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.hi_train.csv
# Error loading mlqa-translate-train.hi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.hi_validation.csv
# Error loading mlqa-translate-train.vi_train.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.vi_train.csv
# Error loading mlqa-translate-train.vi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.vi_validation.csv
# Error loading mlqa-translate-train.zh_train.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.zh_train.csv
# Error loading mlqa-translate-train.zh_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa-translate-train.zh_validation.csv
# Error loading mlqa.ar.ar_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.ar_test.csv
# Error loading mlqa.ar.ar_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.ar_validation.csv
# Error loading mlqa.ar.de_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.de_test.csv
# Error loading mlqa.ar.de_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.de_validation.csv
# Error loading mlqa.ar.en_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.en_test.csv
# Error loading mlqa.ar.en_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.en_validation.csv
# Error loading mlqa.ar.es_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.es_test.csv
# Error loading mlqa.ar.es_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.es_validation.csv
# Error loading mlqa.ar.hi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.hi_test.csv
# Error loading mlqa.ar.hi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.hi_validation.csv
# Error loading mlqa.ar.vi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.vi_test.csv
# Error loading mlqa.ar.vi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.vi_validation.csv
# Error loading mlqa.ar.zh_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.zh_test.csv
# Error loading mlqa.ar.zh_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.ar.zh_validation.csv
# Error loading mlqa.de.ar_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.ar_test.csv
# Error loading mlqa.de.ar_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.ar_validation.csv
# Error loading mlqa.de.de_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.de_test.csv
# Error loading mlqa.de.de_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.de_validation.csv
# Error loading mlqa.de.en_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.en_test.csv
# Error loading mlqa.de.en_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.en_validation.csv
# Error loading mlqa.de.es_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.es_test.csv
# Error loading mlqa.de.es_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.es_validation.csv
# Error loading mlqa.de.hi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.hi_test.csv
# Error loading mlqa.de.hi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.hi_validation.csv
# Error loading mlqa.de.vi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.vi_test.csv
# Error loading mlqa.de.vi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.vi_validation.csv
# Error loading mlqa.de.zh_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.zh_test.csv
# Error loading mlqa.de.zh_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.de.zh_validation.csv
# Error loading mlqa.en.ar_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.ar_test.csv
# Error loading mlqa.en.ar_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.ar_validation.csv
# Error loading mlqa.en.de_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.de_test.csv
# Error loading mlqa.en.de_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.de_validation.csv
# Error loading mlqa.en.en_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.en_test.csv
# Error loading mlqa.en.en_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.en_validation.csv
# Error loading mlqa.en.es_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.es_test.csv
# Error loading mlqa.en.es_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.es_validation.csv
# Error loading mlqa.en.hi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.hi_test.csv
# Error loading mlqa.en.hi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.hi_validation.csv
# Error loading mlqa.en.vi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.vi_test.csv
# Error loading mlqa.en.vi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.vi_validation.csv
# Error loading mlqa.en.zh_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.zh_test.csv
# Error loading mlqa.en.zh_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.en.zh_validation.csv
# Error loading mlqa.es.ar_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.ar_test.csv
# Error loading mlqa.es.ar_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.ar_validation.csv
# Error loading mlqa.es.de_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.de_test.csv
# Error loading mlqa.es.de_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.de_validation.csv
# Error loading mlqa.es.en_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.en_test.csv
# Error loading mlqa.es.en_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.en_validation.csv
# Error loading mlqa.es.es_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.es_test.csv
# Error loading mlqa.es.es_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.es_validation.csv
# Error loading mlqa.es.hi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.hi_test.csv
# Error loading mlqa.es.hi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.hi_validation.csv
# Error loading mlqa.es.vi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.vi_test.csv
# Error loading mlqa.es.vi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.vi_validation.csv
# Error loading mlqa.es.zh_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.zh_test.csv
# Error loading mlqa.es.zh_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.es.zh_validation.csv
# Error loading mlqa.hi.ar_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.ar_test.csv
# Error loading mlqa.hi.ar_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.ar_validation.csv
# Error loading mlqa.hi.de_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.de_test.csv
# Error loading mlqa.hi.de_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.de_validation.csv
# Error loading mlqa.hi.en_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.en_test.csv
# Error loading mlqa.hi.en_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.en_validation.csv
# Error loading mlqa.hi.es_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.es_test.csv
# Error loading mlqa.hi.es_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.es_validation.csv
# Error loading mlqa.hi.hi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.hi_test.csv
# Error loading mlqa.hi.hi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.hi_validation.csv
# Error loading mlqa.hi.vi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.vi_test.csv
# Error loading mlqa.hi.vi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.vi_validation.csv
# Error loading mlqa.hi.zh_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.zh_test.csv
# Error loading mlqa.hi.zh_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.hi.zh_validation.csv
# Error loading mlqa.vi.ar_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.ar_test.csv
# Error loading mlqa.vi.ar_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.ar_validation.csv
# Error loading mlqa.vi.de_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.de_test.csv
# Error loading mlqa.vi.de_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.de_validation.csv
# Error loading mlqa.vi.en_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.en_test.csv
# Error loading mlqa.vi.en_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.en_validation.csv
# Error loading mlqa.vi.es_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.es_test.csv
# Error loading mlqa.vi.es_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.es_validation.csv
# Error loading mlqa.vi.hi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.hi_test.csv
# Error loading mlqa.vi.hi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.hi_validation.csv
# Error loading mlqa.vi.vi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.vi_test.csv
# Error loading mlqa.vi.vi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.vi_validation.csv
# Error loading mlqa.vi.zh_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.zh_test.csv
# Error loading mlqa.vi.zh_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.vi.zh_validation.csv
# Error loading mlqa.zh.ar_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.ar_test.csv
# Error loading mlqa.zh.ar_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.ar_validation.csv
# Error loading mlqa.zh.de_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.de_test.csv
# Error loading mlqa.zh.de_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.de_validation.csv
# Error loading mlqa.zh.en_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.en_test.csv
# Error loading mlqa.zh.en_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.en_validation.csv
# Error loading mlqa.zh.es_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.es_test.csv
# Error loading mlqa.zh.es_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.es_validation.csv
# Error loading mlqa.zh.hi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.hi_test.csv
# Error loading mlqa.zh.hi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.hi_validation.csv
# Error loading mlqa.zh.vi_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.vi_test.csv
# Error loading mlqa.zh.vi_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.vi_validation.csv
# Error loading mlqa.zh.zh_test.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.zh_test.csv
# Error loading mlqa.zh.zh_validation.csv: Error loading D:\GUVI\myenv\AI_Document_QA_System\Data\mlqa.zh.zh_validation.csv
# Error loading train-v1.1.json: Expected page_content is string, got <class 'list'> instead.                     Set `text_content=False` if the desired input for                     `page_content` is not a string
# Total documents loaded: 165

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = splitter.split_documents(documents)

print("Total chunks:", len(chunks))
# Out:
# Total chunks: 165

# %%
# %pip install sentence-transformers transformers
# Out:
# Requirement already satisfied: sentence-transformers in d:\guvi\myenv\lib\site-packages (5.3.0)
# Requirement already satisfied: transformers in d:\guvi\myenv\lib\site-packages (5.4.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in d:\guvi\myenv\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: torch>=1.11.0 in d:\guvi\myenv\lib\site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: numpy in d:\guvi\myenv\lib\site-packages (from sentence-transformers) (2.3.2)
# Requirement already satisfied: scikit-learn in d:\guvi\myenv\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in d:\guvi\myenv\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\guvi\myenv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in d:\guvi\myenv\lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in d:\guvi\myenv\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\guvi\myenv\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in d:\guvi\myenv\lib\site-packages (from transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in d:\guvi\myenv\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in d:\guvi\myenv\lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in d:\guvi\myenv\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in d:\guvi\myenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\guvi\myenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in d:\guvi\myenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\guvi\myenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in d:\guvi\myenv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.13.0)
# Requirement already satisfied: certifi in d:\guvi\myenv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\guvi\myenv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in d:\guvi\myenv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\guvi\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: setuptools<82 in d:\guvi\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\guvi\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\guvi\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in d:\guvi\myenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\guvi\myenv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in d:\guvi\myenv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\guvi\myenv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.3.0 in d:\guvi\myenv\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in d:\guvi\myenv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: click>=8.2.1 in d:\guvi\myenv\lib\site-packages (from typer->transformers) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in d:\guvi\myenv\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in d:\guvi\myenv\lib\site-packages (from typer->transformers) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\guvi\myenv\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\guvi\myenv\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\guvi\myenv\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\guvi\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2"
)
# Out:
# C:\Users\ravi9\AppData\Local\Temp\ipykernel_17460\965671690.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# d:\GUVI\myenv\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ravi9\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 8904.92it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
from transformers import pipeline

qa_pipeline = pipeline(
    "text-generation",
    model="google/flan-t5-base",
    max_new_tokens=200
)
# Out:
# Loading weights: 100%|██████████| 282/282 [00:00<00:00, 7820.07it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# The model 'T5ForConditionalGeneration' is not supported for text-generation. Supported models are ['PeftModelForCausalLM', 'AfmoeForCausalLM', 'ApertusForCausalLM', 'ArceeForCausalLM', 'AriaTextForCausalLM', 'BambaForCausalLM', 'BartForCausalLM', 'BertLMHeadModel', 'BertGenerationDecoder', 'BigBirdForCausalLM', 'BigBirdPegasusForCausalLM', 'BioGptForCausalLM', 'BitNetForCausalLM', 'BlenderbotForCausalLM', 'BlenderbotSmallForCausalLM', 'BloomForCausalLM', 'BltForCausalLM', 'CamembertForCausalLM', 'LlamaForCausalLM', 'CodeGenForCausalLM', 'CohereForCausalLM', 'Cohere2ForCausalLM', 'CpmAntForCausalLM', 'CTRLLMHeadModel', 'CwmForCausalLM', 'Data2VecTextForCausalLM', 'DbrxForCausalLM', 'DeepseekV2ForCausalLM', 'DeepseekV3ForCausalLM', 'DiffLlamaForCausalLM', 'DogeForCausalLM', 'Dots1ForCausalLM', 'ElectraForCausalLM', 'Emu3ForCausalLM', 'ErnieForCausalLM', 'Ernie4_5ForCausalLM', 'Ernie4_5_MoeForCausalLM', 'Exaone4ForCausalLM', 'ExaoneMoeForCausalLM', 'FalconForCausalLM', 'FalconH1ForCausalLM', 'FalconMambaForCausalLM', 'FlexOlmoForCausalLM', 'FuyuForCausalLM', 'GemmaForCausalLM', 'Gemma2ForCausalLM', 'Gemma3ForConditionalGeneration', 'Gemma3ForCausalLM', 'Gemma3nForConditionalGeneration', 'Gemma3nForCausalLM', 'GitForCausalLM', 'GlmForCausalLM', 'Glm4ForCausalLM', 'Glm4MoeForCausalLM', 'Glm4MoeLiteForCausalLM', 'GlmMoeDsaForCausalLM', 'GotOcr2ForConditionalGeneration', 'GPT2LMHeadModel', 'GPT2LMHeadModel', 'GPTBigCodeForCausalLM', 'GPTNeoForCausalLM', 'GPTNeoXForCausalLM', 'GPTNeoXJapaneseForCausalLM', 'GptOssForCausalLM', 'GPTJForCausalLM', 'GraniteForCausalLM', 'GraniteMoeForCausalLM', 'GraniteMoeHybridForCausalLM', 'GraniteMoeSharedForCausalLM', 'HeliumForCausalLM', 'HunYuanDenseV1ForCausalLM', 'HunYuanMoEV1ForCausalLM', 'Jais2ForCausalLM', 'JambaForCausalLM', 'JetMoeForCausalLM', 'Lfm2ForCausalLM', 'Lfm2MoeForCausalLM', 'LlamaForCausalLM', 'Llama4ForCausalLM', 'Llama4ForCausalLM', 'LongcatFlashForCausalLM', 'MambaForCausalLM', 'Mamba2ForCausalLM', 'MarianForCausalLM', 'MBartForCausalLM', 'MegatronBertForCausalLM', 'MiniMaxForCausalLM', 'MiniMaxM2ForCausalLM', 'MinistralForCausalLM', 'Ministral3ForCausalLM', 'MistralForCausalLM', 'MixtralForCausalLM', 'MllamaForCausalLM', 'ModernBertDecoderForCausalLM', 'MoshiForCausalLM', 'MptForCausalLM', 'MusicgenForCausalLM', 'MusicgenMelodyForCausalLM', 'MvpForCausalLM', 'NanoChatForCausalLM', 'NemotronForCausalLM', 'NemotronHForCausalLM', 'OlmoForCausalLM', 'Olmo2ForCausalLM', 'Olmo3ForCausalLM', 'OlmoHybridForCausalLM', 'OlmoeForCausalLM', 'OpenAIGPTLMHeadModel', 'OPTForCausalLM', 'PegasusForCausalLM', 'PersimmonForCausalLM', 'PhiForCausalLM', 'Phi3ForCausalLM', 'Phi4MultimodalForCausalLM', 'PhimoeForCausalLM', 'PLBartForCausalLM', 'ProphetNetForCausalLM', 'Qwen2ForCausalLM', 'Qwen2MoeForCausalLM', 'Qwen3ForCausalLM', 'Qwen3_5ForCausalLM', 'Qwen3_5MoeForCausalLM', 'Qwen3_5MoeForCausalLM', 'Qwen3_5ForCausalLM', 'Qwen3MoeForCausalLM', 'Qwen3NextForCausalLM', 'RecurrentGemmaForCausalLM', 'ReformerModelWithLMHead', 'RemBertForCausalLM', 'RobertaForCausalLM', 'RobertaPreLayerNormForCausalLM', 'RoCBertForCausalLM', 'RoFormerForCausalLM', 'RwkvForCausalLM', 'SeedOssForCausalLM', 'SmolLM3ForCausalLM', 'SolarOpenForCausalLM', 'StableLmForCausalLM', 'Starcoder2ForCausalLM', 'TrOCRForCausalLM', 'VaultGemmaForCausalLM', 'WhisperForCausalLM', 'XGLMForCausalLM', 'XLMWithLMHeadModel', 'XLMRobertaForCausalLM', 'XLMRobertaXLForCausalLM', 'XLNetLMHeadModel', 'xLSTMForCausalLM', 'XmodForCausalLM', 'YoutuForCausalLM', 'ZambaForCausalLM', 'Zamba2ForCausalLM'].

# %%
def generate_answer(query, docs):
    context = "\n".join([doc.page_content for doc in docs])

    prompt = f"""
    Answer based ONLY on context.
    If not found, say "I don't know".

    Context:
    {context}

    Question:
    {query}
    """

    result = qa_pipeline(prompt)
    return result[0]['generated_text']

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in d:\guvi\myenv\lib\site-packages (1.50.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in d:\guvi\myenv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in d:\guvi\myenv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in d:\guvi\myenv\lib\site-packages (from streamlit) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in d:\guvi\myenv\lib\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in d:\guvi\myenv\lib\site-packages (from streamlit) (2.3.2)
# Requirement already satisfied: packaging<26,>=20 in d:\guvi\myenv\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in d:\guvi\myenv\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in d:\guvi\myenv\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in d:\guvi\myenv\lib\site-packages (from streamlit) (6.32.1)
# Requirement already satisfied: pyarrow>=7.0 in d:\guvi\myenv\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in d:\guvi\myenv\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in d:\guvi\myenv\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in d:\guvi\myenv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in d:\guvi\myenv\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in d:\guvi\myenv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in d:\guvi\myenv\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in d:\guvi\myenv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in d:\guvi\myenv\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in d:\guvi\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in d:\guvi\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in d:\guvi\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.7.0)
# Requirement already satisfied: colorama in d:\guvi\myenv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\guvi\myenv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\guvi\myenv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\guvi\myenv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\guvi\myenv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\guvi\myenv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\guvi\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\guvi\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\guvi\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\guvi\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\guvi\myenv\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\guvi\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\guvi\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\guvi\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\guvi\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in d:\guvi\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile app.py

import streamlit as st
import os

from langchain_community.document_loaders import TextLoader, CSVLoader, JSONLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
from transformers import pipeline

st.set_page_config(page_title="AI Document QA", layout="wide")

st.title("📄 AI Document QA System (RAG)")
st.write("Upload TXT, CSV, JSON files and ask questions")

# -------------------------
# LOAD FILES
# -------------------------
def load_documents(uploaded_files):
    docs = []
    for file in uploaded_files:
        path = file.name
        with open(path, "wb") as f:
            f.write(file.getbuffer())

        if file.name.endswith(".txt"):
            loader = TextLoader(path)
        elif file.name.endswith(".csv"):
            loader = CSVLoader(path)
        elif file.name.endswith(".json"):
            loader = JSONLoader(path, jq_schema=".[]")
        else:
            continue

        file_docs = loader.load()

        for d in file_docs:
            d.metadata["source"] = file.name

        docs.extend(file_docs)

    return docs

# -------------------------
# PROCESS
# -------------------------
def process_docs(docs):
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=500,
        chunk_overlap=50
    )

    chunks = splitter.split_documents(docs)

    embeddings = HuggingFaceEmbeddings(
        model_name="all-MiniLM-L6-v2"
    )

    return FAISS.from_documents(chunks, embeddings)

# -------------------------
# MODEL
# -------------------------
@st.cache_resource
def load_model():
    return pipeline("text-generation", model="google/flan-t5-small", max_new_tokens=200)

model = load_model()

# -------------------------
# ANSWER
# -------------------------
def get_answer(query, docs):
    context = "\n".join([d.page_content for d in docs])

    prompt = f"""
    Answer ONLY from context.
    If not found, say "I don't know".

    Context:
    {context}

    Question:
    {query}
    """

    result = model(prompt)
    return result[0]["generated_text"].replace(prompt, "").strip()

# -------------------------
# UI
# -------------------------
files = st.file_uploader("Upload files", type=["txt","csv","json"], accept_multiple_files=True)

if files:
    if st.button("Process"):
        with st.spinner("Processing..."):
            docs = load_documents(files)
            st.session_state.vs = process_docs(docs)
        st.success("Done!")

query = st.text_input("Ask question")

if query and "vs" in st.session_state:
    docs = st.session_state.vs.similarity_search(query, k=3)
    answer = get_answer(query, docs)

    st.subheader("Answer")
    st.write(answer)

    st.subheader("Sources")
    for d in docs:
        st.write(d.metadata["source"])
        st.write(d.page_content[:200])
        st.write("---")
# Out:
# Writing app.py

# %%
# !streamlit run app.py
# Out:
# ^C
